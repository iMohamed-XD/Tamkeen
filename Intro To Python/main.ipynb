# %%
def swap(a, b):
    return b, a

# %%
a = 4
b = 5
swapped_a, swapped_b = swap(a, b)
print("Before swapping: a =", a, ", b =", b)
print("After swapping: a =", swapped_a, ", b =", swapped_b)
# Out:
# Before swapping: a = 4 , b = 5
# After swapping: a = 5 , b = 4
